# %% [markdown]
# ## Setup

# %%
# Clone the repo including pretrained models
# !git clone https://github.com/as-ideas/ForwardTacotron.git
# Out:
# Cloning into 'ForwardTacotron'...
# remote: Enumerating objects: 7831, done.
# remote: Counting objects: 100% (1611/1611), done.
# remote: Compressing objects: 100% (510/510), done.
# remote: Total 7831 (delta 1210), reused 1436 (delta 1093), pack-reused 6220
# Receiving objects: 100% (7831/7831), 207.26 MiB | 6.38 MiB/s, done.
# Resolving deltas: 100% (5493/5493), done.

# %%
# Install requirements
# %cd ForwardTacotron/  
# !apt-get install espeak
# !pip install -r requirements.txt
# Out:
# /Users/cschaefe/workspace/ForwardTacotron/notebooks/ForwardTacotron
# zsh:1: command not found: apt-get
# Collecting numba==0.49.1
#   Using cached numba-0.49.1.tar.gz (2.0 MB)
#   Preparing metadata (setup.py) ... done
# Collecting librosa==0.7.2
#   Using cached librosa-0.7.2.tar.gz (1.6 MB)
#   Preparing metadata (setup.py) ... done
# Collecting pyworld>=0.2.10
#   Using cached pyworld-0.3.2.tar.gz (214 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting torch>=1.2.0
#   Downloading torch-1.13.1-cp310-none-macosx_10_9_x86_64.whl (135.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 MB 5.9 MB/s eta 0:00:0000:0100:01
# Collecting phonemizer>=2.2
#   Using cached phonemizer-3.2.1-py3-none-any.whl (90 kB)
# Collecting webrtcvad>=2.0.10
#   Using cached webrtcvad-2.0.10.tar.gz (66 kB)
#   Preparing metadata (setup.py) ... done
# Collecting PyYAML>=5.1
#   Downloading PyYAML-6.0-cp310-cp310-macosx_10_9_x86_64.whl (197 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.6/197.6 kB 5.7 MB/s eta 0:00:00
# Collecting tqdm
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# Collecting dataclasses
#   Using cached dataclasses-0.6-py3-none-any.whl (14 kB)
# Collecting soundfile
#   Using cached soundfile-0.11.0-py2.py3-none-macosx_10_9_x86_64.macosx_11_0_x86_64.whl (1.2 MB)
# Collecting scipy
#   Downloading scipy-1.10.0-cp310-cp310-macosx_10_15_x86_64.whl (35.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.1/35.1 MB 5.1 MB/s eta 0:00:0000:0100:01
# Collecting tensorboard
#   Downloading tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 6.4 MB/s eta 0:00:0000:0100:01
# Collecting matplotlib
#   Downloading matplotlib-3.6.3-cp310-cp310-macosx_10_12_x86_64.whl (7.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 6.6 MB/s eta 0:00:0000:0100:01
# Collecting unidecode
#   Using cached Unidecode-1.3.6-py3-none-any.whl (235 kB)
# Collecting inflect
#   Using cached inflect-6.0.2-py3-none-any.whl (34 kB)
# Collecting resemblyzer==0.1.1-dev
#   Using cached Resemblyzer-0.1.1.dev0-py3-none-any.whl (15.7 MB)
# Collecting llvmlite<=0.33.0.dev0,>=0.31.0.dev0
#   Using cached llvmlite-0.32.1.tar.gz (104 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.15 in /Users/cschaefe/anaconda3/envs/notebook/lib/python3.10/site-packages (from numba==0.49.1->-r requirements.txt (line 1)) (1.23.3)
# Requirement already satisfied: setuptools in /Users/cschaefe/anaconda3/envs/notebook/lib/python3.10/site-packages (from numba==0.49.1->-r requirements.txt (line 1)) (65.3.0)
# Collecting audioread>=2.0.0
#   Using cached audioread-3.0.0-py3-none-any.whl
# Collecting scikit-learn!=0.19.0,>=0.14.0
#   Downloading scikit_learn-1.2.1-cp310-cp310-macosx_10_9_x86_64.whl (9.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 6.7 MB/s eta 0:00:0000:0100:01
# Collecting joblib>=0.12
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Requirement already satisfied: decorator>=3.0.0 in /Users/cschaefe/anaconda3/envs/notebook/lib/python3.10/site-packages (from librosa==0.7.2->-r requirements.txt (line 2)) (5.1.1)
# Requirement already satisfied: six>=1.3 in /Users/cschaefe/anaconda3/envs/notebook/lib/python3.10/site-packages (from librosa==0.7.2->-r requirements.txt (line 2)) (1.16.0)
# Collecting resampy>=0.2.2
#   Using cached resampy-0.4.2-py3-none-any.whl (3.1 MB)
# Collecting typing
#   Using cached typing-3.7.4.3.tar.gz (78 kB)
#   Preparing metadata (setup.py) ... done
# Collecting cython
#   Using cached Cython-0.29.33-py2.py3-none-any.whl (987 kB)
# Collecting typing-extensions
#   Using cached typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Collecting segments
#   Using cached segments-2.2.1-py2.py3-none-any.whl (15 kB)
# Collecting dlinfo
#   Using cached dlinfo-1.2.1-py3-none-any.whl (3.6 kB)
# Requirement already satisfied: attrs>=18.1 in /Users/cschaefe/anaconda3/envs/notebook/lib/python3.10/site-packages (from phonemizer>=2.2->-r requirements.txt (line 5)) (22.1.0)
# Requirement already satisfied: cffi>=1.0 in /Users/cschaefe/anaconda3/envs/notebook/lib/python3.10/site-packages (from soundfile->-r requirements.txt (line 10)) (1.15.1)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.4.1-py3-none-any.whl (93 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Collecting werkzeug>=1.0.1
#   Using cached Werkzeug-2.2.2-py3-none-any.whl (232 kB)
# Collecting protobuf<4,>=3.9.2
#   Downloading protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 4.3 MB/s eta 0:00:00
# Collecting absl-py>=0.4
#   Downloading absl_py-1.4.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.5/126.5 kB 2.8 MB/s eta 0:00:00a 0:00:01
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-macosx_10_9_x86_64.whl (3.5 MB)
# Collecting grpcio>=1.24.3
#   Downloading grpcio-1.51.1-cp310-cp310-macosx_12_0_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 6.5 MB/s eta 0:00:0000:0100:01
# Collecting requests<3,>=2.21.0
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 3.5 MB/s eta 0:00:00
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: wheel>=0.26 in /Users/cschaefe/anaconda3/envs/notebook/lib/python3.10/site-packages (from tensorboard->-r requirements.txt (line 12)) (0.37.1)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.16.0-py2.py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.8/177.8 kB 4.6 MB/s eta 0:00:0000:01
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/cschaefe/anaconda3/envs/notebook/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 13)) (21.3)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.4.0-2-cp310-cp310-macosx_10_10_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 6.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /Users/cschaefe/anaconda3/envs/notebook/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 13)) (2.8.2)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp310-cp310-macosx_10_9_x86_64.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 3.3 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp310-cp310-macosx_10_9_x86_64.whl (244 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 5.6 MB/s eta 0:00:00a 0:00:01
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.38.0-py3-none-any.whl (965 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/cschaefe/anaconda3/envs/notebook/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 13)) (3.0.9)
# Collecting pydantic>=1.9.1
#   Downloading pydantic-1.10.4-cp310-cp310-macosx_10_9_x86_64.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 6.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pycparser in /Users/cschaefe/anaconda3/envs/notebook/lib/python3.10/site-packages (from cffi>=1.0->soundfile->-r requirements.txt (line 10)) (2.21)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 5.8 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.0.1-cp310-cp310-macosx_10_9_x86_64.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 kB 4.7 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Using cached certifi-2022.12.7-py3-none-any.whl (155 kB)
# Collecting resampy>=0.2.2
#   Using cached resampy-0.4.1-py3-none-any.whl (3.1 MB)
#   Using cached resampy-0.4.0-py3-none-any.whl (3.1 MB)
#   Using cached resampy-0.3.1-py3-none-any.whl (3.1 MB)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/cschaefe/anaconda3/envs/notebook/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard->-r requirements.txt (line 12)) (2.1.1)
# Collecting regex
#   Downloading regex-2022.10.31-cp310-cp310-macosx_10_9_x86_64.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.9/293.9 kB 6.3 MB/s eta 0:00:00a 0:00:01
# Collecting csvw>=1.5.6
#   Using cached csvw-3.1.3-py2.py3-none-any.whl (56 kB)
# Collecting clldutils>=1.7.3
#   Downloading clldutils-3.19.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 6.7 MB/s eta 0:00:0000:0100:01m
# Collecting colorlog
#   Using cached colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: lxml in /Users/cschaefe/anaconda3/envs/notebook/lib/python3.10/site-packages (from clldutils>=1.7.3->segments->phonemizer>=2.2->-r requirements.txt (line 5)) (4.9.1)
# Collecting tabulate>=0.7.7
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting pylatexenc
#   Using cached pylatexenc-2.10.tar.gz (162 kB)
#   Preparing metadata (setup.py) ... done
# Collecting rdflib
#   Using cached rdflib-6.2.0-py3-none-any.whl (500 kB)
# Collecting language-tags
#   Downloading language_tags-1.2.0-py3-none-any.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/213.4 kB ? eta -:--:--

# %%
# Get pretrained models
# !wget https://public-asai-dl-models.s3.eu-central-1.amazonaws.com/ForwardTacotron/forward_step90k.pt
# !wget https://public-asai-dl-models.s3.eu-central-1.amazonaws.com/ForwardTacotron/fastpitch_step200k.pt
# Out:
# --2021-08-24 10:49:22--  https://public-asai-dl-models.s3.eu-central-1.amazonaws.com/ForwardTacotron/forward_step90k.pt
# Resolving public-asai-dl-models.s3.eu-central-1.amazonaws.com (public-asai-dl-models.s3.eu-central-1.amazonaws.com)... 52.219.75.244
# Connecting to public-asai-dl-models.s3.eu-central-1.amazonaws.com (public-asai-dl-models.s3.eu-central-1.amazonaws.com)|52.219.75.244|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 292356811 (279M) [application/x-www-form-urlencoded]
# Saving to: ‘forward_step90k.pt’
#
# forward_step90k.pt  100%[===================>] 278.81M  38.4MB/s    in 6.1s
#
# 2021-08-24 10:49:28 (45.6 MB/s) - ‘forward_step90k.pt’ saved [292356811/292356811]
#
# --2021-08-24 10:49:28--  https://public-asai-dl-models.s3.eu-central-1.amazonaws.com/ForwardTacotron/fastpitch_step200k.pt
# Resolving public-asai-dl-models.s3.eu-central-1.amazonaws.com (public-asai-dl-models.s3.eu-central-1.amazonaws.com)... 52.219.47.245
# Connecting to public-asai-dl-models.s3.eu-central-1.amazonaws.com (public-asai-dl-models.s3.eu-central-1.amazonaws.com)|52.219.47.245|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 329900474 (315M) [application/x-www-form-urlencoded]
# Saving to: ‘fastpitch_step200k.pt’
#
# fastpitch_step200k. 100%[===================>] 314.62M  74.9MB/s    in 4.1s
#
# 2021-08-24 10:49:33 (77.2 MB/s) - ‘fastpitch_step200k.pt’ saved [329900474/329900474]
#
# --2021-08-24 10:49:33--  https://public-asai-dl-models.s3.eu-central-1.amazonaws.com/ForwardTacotron/wave_step575k.pt
# Resolving public-asai-dl-models.s3.eu-central-1.amazonaws.com (public-asai-dl-models.s3.eu-central-1.amazonaws.com)... 52.219.47.84
# Connecting to public-asai-dl-models.s3.eu-central-1.amazonaws.com (public-asai-dl-models.s3.eu-central-1.amazonaws.com)|52.219.47.84|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18000187 (17M) [application/x-www-form-urlencoded]
# Saving to: ‘wave_step575k.pt’
#
# wave_step575k.pt    100%[===================>]  17.17M  92.5MB/s    in 0.2s
#
# 2021-08-24 10:49:33 (92.5 MB/s) - ‘wave_step575k.pt’ saved [18000187/18000187]

# %%
# Load pretrained models
from notebook_utils.synthesize import Synthesizer
import IPython.display as ipd
synth_forward = Synthesizer(tts_path='forward_step90k.pt')
synth_fastpitch = Synthesizer(tts_path='fastpitch_step200k.pt')
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# /usr/local/lib/python3.7/dist-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'jit' requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# Downloading: "https://github.com/seungwonpark/melgan/archive/master.zip" to /root/.cache/torch/hub/master.zip
# Downloading: "https://github.com/seungwonpark/melgan/releases/download/v0.3-alpha/nvidia_tacotron2_LJ11_epoch6400.pt" to /root/.cache/torch/hub/checkpoints/nvidia_tacotron2_LJ11_epoch6400.pt
#   0%|          | 0.00/16.3M [00:00<?, ?B/s]
# Using cache found in /root/.cache/torch/hub/seungwonpark_melgan_master

# %% [markdown]
# ##Synthesize

# %%
# Synthesize with forward_tacotron and melgan (alpha=1.0)
input_text = 'There is a way to measure the acute emotional intelligence that has never gone out of style.'
wav = synth_forward(input_text, voc_model='melgan', alpha=1)
ipd.Audio(wav, rate=synth_forward.dsp.sample_rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Synthesize faster (alpha=1.2)
input_text = 'There is a way to measure the acute emotional intelligence that has never gone out of style.'
wav = synth_fastpitch(input_text, voc_model='melgan', alpha=1.2)
ipd.Audio(wav, rate=synth_fastpitch.dsp.sample_rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Synthesize with amplified pitch
input_text = 'There is a way to measure the acute emotional intelligence that has never gone out of style.'
pitch_func = lambda x: x * 1.5
wav = synth_fastpitch(input_text, voc_model='melgan', alpha=1, pitch_function=pitch_func)
ipd.Audio(wav, rate=synth_fastpitch.dsp.sample_rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
